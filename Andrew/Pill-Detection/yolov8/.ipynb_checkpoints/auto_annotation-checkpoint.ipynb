# %%
from ultralytics import YOLO

# %%
# Initialize YOLO model
model = YOLO('detect_pills.pt')

# %%
# Set the path to the single image
results = model(r'C:\Users\fangg\OneDrive\Documents\FYP_yolov8\Upload_Image\heart\heart1.jpeg')

# View results
for r in results:
    print(r.boxes.xywhn.tolist()[0])
# Out:
# image 1/1 C:\Users\fangg\OneDrive\Documents\FYP_yolov8\Upload_Image\heart\heart1.jpeg: 640x384 1 pill, 166.4ms
# Speed: 12.8ms preprocess, 166.4ms inference, 461.6ms postprocess per image at shape (1, 3, 640, 384)
# [0.4955874979496002, 0.5285820364952087, 0.15328174829483032, 0.20904728770256042]

# %%
import os
import Augmentor

# Function to apply augmentation to each subfolder
def augment_images_in_folder(folder_path, num_augmented_images):
    pipeline = Augmentor.Pipeline(folder_path)
    
    # Define augmentation operations
    pipeline.flip_left_right(probability=0.7)
    pipeline.random_brightness(probability=0.5, min_factor=0.5, max_factor=1.4)
    pipeline.rotate90(probability=0.6)
    pipeline.zoom_random(probability=0.5, percentage_area=0.8)

    pipeline.sample(num_augmented_images)

# Main script
input_folder = './Upload_Image/'

# Iterate through subfolders and apply augmentation
for subfolder in os.listdir(input_folder):
    subfolder_path = os.path.join(input_folder, subfolder)
    
    # Check if it's a directory
    if os.path.isdir(subfolder_path):
        print(f"Augmenting images in folder: {subfolder}")
        augment_images_in_folder(subfolder_path, 100)

print("Augmentation complete.")
# Out:
# Augmenting images in folder: gastric
# Initialised with 2 image(s) found.
# Output directory set to ./Upload_Image/gastric\output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1152 at 0x2537FB0FC90>: 100%|█| 100/100 [00:02<00:00, 38.23 Sample
# Augmenting images in folder: heart
# Initialised with 2 image(s) found.
# Output directory set to ./Upload_Image/heart\output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1152 at 0x2537FABCD10>: 100%|█| 100/100 [00:02<00:00, 42.25 Sample
# Augmenting images in folder: ibuprofen
# Initialised with 2 image(s) found.
# Output directory set to ./Upload_Image/ibuprofen\output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1152 at 0x2537FAEAC10>: 100%|█| 100/100 [00:02<00:00, 37.99 Sample
# Augmenting images in folder: nausea
# Initialised with 2 image(s) found.
# Output directory set to ./Upload_Image/nausea\output.
# Processing <PIL.Image.Image image mode=RGB size=1152x2048 at 0x2537FB5DB10>: 100%|█| 100/100 [00:02<00:00, 38.05 Sample
# Augmenting images in folder: panadol
# Initialised with 2 image(s) found.
# Output directory set to ./Upload_Image/panadol\output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1152 at 0x2537FACFD10>: 100%|█| 100/100 [00:02<00:00, 38.72 Sample
# Augmentation complete.

# %%
import os
import cv2
import yaml

input_root_folder = './Upload_Image/'
output_root_folder = './Annotated/'
augmented_folder = 'output'  # Adjust this according to the new structure
data_yaml_path = 'data.yaml'

# load the model
yolo = YOLO('detect_pills.pt')

# update the data.yaml file with new classes
def update_data_yaml(data_yaml_path, new_class):

    if not os.path.exists(data_yaml_path):  # Check if the file exists
        with open(data_yaml_path, 'w') as file:  # Create an empty YAML file with the necessary structure
            yaml.dump({'nc': 0, 'names': []}, file)

    with open(data_yaml_path, 'r') as file:  # Load the existing YAML content
        data = yaml.load(file, Loader=yaml.FullLoader)

    if not data['names']:  # Check if the new class already exists (case-insensitive check)
        data['names'] = [new_class]  # Initialize the data['names'] to be a list
        data['nc'] = 1
        with open(data_yaml_path, 'w') as file:
            yaml.dump(data, file)
        print(f"Class '{new_class}' added to {data_yaml_path}")

    else:  # Append new classes if data['names'] is already a list
        if new_class not in [existing_class.lower() for existing_class in data['names']]:  # Check for duplicate names
            data['names'].append(new_class)  # Add the new class to the list of names
            data['nc'] = len(set([name.lower() for name in data['names']]))  # Update the count of classes

            with open(data_yaml_path, 'w') as file:  # Save the updated YAML content
                yaml.dump(data, file)
            print(f"Class '{new_class}' added to {data_yaml_path}")

        else:
            print(f"Class '{new_class}' already exists in {data_yaml_path}")

    return data['names']

# Main script
for pill_folder in os.listdir(input_root_folder):  # iterate through the image folders
    pill_folder_path = os.path.join(input_root_folder, pill_folder)
    if os.path.isdir(pill_folder_path):  # Check if the folder is a directory

        if pill_folder != augmented_folder:  # Augmented_Photos folder is for storing the augmented uploaded images
            new_class_name = pill_folder  # Use the name of the image folder as the class name
            class_names = update_data_yaml(data_yaml_path, new_class_name)  # Update YAML file
            one_hot_encoding = {class_name: index for index, class_name in enumerate(class_names)}  # Perform one-hot encoding
        
            augmented_folder_path = os.path.join(pill_folder_path, augmented_folder)  # Path to the augmented images
            
            for pic_name in os.listdir(augmented_folder_path):  # Iterate through files in the augmented subfolder
                
                if pic_name.lower().endswith(('.png', '.jpg', '.jpeg')):  # Check if the file is an image
                    img_path = os.path.join(augmented_folder_path, pic_name)  # Adjust the path to the augmented images
                    
                    img = cv2.imread(img_path)  # Load the image
                    original = img.copy()
                    
                    # Check for existing files with the same name
                    existing_count = 0
                    base_name = os.path.splitext(pic_name)[0]  # Remove the extension
                    while True:
                        annotated_txt_path = os.path.join(output_root_folder, pill_folder, f'{base_name}{existing_count}.txt')
                        annotated_img_path = os.path.join(output_root_folder, pill_folder, f'{base_name}{existing_count}.jpeg')

                        if not os.path.exists(os.path.dirname(annotated_txt_path)):
                            os.makedirs(os.path.dirname(annotated_txt_path))

                        if not os.path.exists(os.path.dirname(annotated_img_path)):
                            os.makedirs(os.path.dirname(annotated_img_path))

                        if not os.path.exists(annotated_txt_path) and not os.path.exists(annotated_img_path):
                            break

                        existing_count += 1

                    results = yolo(img)  # Perform pill detection and label

                    if results:
                        for r in results:
                            if len(r.boxes.xywhn.tolist()) > 0:
                                cv2.imwrite(annotated_img_path, original)
                                x, y, w, h = r.boxes.xywhn.tolist()[0]

                                # Save the normalized center x, center y, width, and height value.
                                # This will be used in the training of the model
                                with open(annotated_txt_path, 'w') as file:
                                    line = f"{one_hot_encoding[pill_folder]} {x} {y} {w} {h}\n"
                                    file.write(line)
# Out:
# Class 'gastric' already exists in data.yaml
#
# 0: 384x640 2 pills, 772.9ms
# Speed: 3.0ms preprocess, 772.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 701.7ms
# Speed: 3.0ms preprocess, 701.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 729.9ms
# Speed: 3.1ms preprocess, 729.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 714.1ms
# Speed: 1.4ms preprocess, 714.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 704.0ms
# Speed: 3.1ms preprocess, 704.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 689.1ms
# Speed: 3.0ms preprocess, 689.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 714.7ms
# Speed: 8.3ms preprocess, 714.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 709.4ms
# Speed: 2.5ms preprocess, 709.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 2 pills, 700.4ms
# Speed: 4.8ms preprocess, 700.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 (no detections), 713.8ms
# Speed: 3.3ms preprocess, 713.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 720.2ms
# Speed: 5.0ms preprocess, 720.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 791.8ms
# Speed: 3.5ms preprocess, 791.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 731.9ms
# Speed: 3.0ms preprocess, 731.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 (no detections), 689.3ms
# Speed: 2.4ms preprocess, 689.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 731.4ms
# Speed: 7.1ms preprocess, 731.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 (no detections), 727.7ms
# Speed: 2.0ms preprocess, 727.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 742.8ms
# Speed: 7.1ms preprocess, 742.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 791.2ms
# Speed: 4.5ms preprocess, 791.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 731.0ms
# Speed: 0.0ms preprocess, 731.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 764.4ms
# Speed: 1.5ms preprocess, 764.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 711.6ms
# Speed: 2.1ms preprocess, 711.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 (no detections), 733.7ms
# Speed: 2.0ms preprocess, 733.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 713.1ms
# Speed: 1.6ms preprocess, 713.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 724.0ms
# Speed: 5.9ms preprocess, 724.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 776.1ms
# Speed: 11.0ms preprocess, 776.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 867.2ms
# Speed: 2.1ms preprocess, 867.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 731.6ms
# Speed: 0.0ms preprocess, 731.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 746.7ms
# Speed: 4.0ms preprocess, 746.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 803.2ms
# Speed: 2.0ms preprocess, 803.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 815.8ms
# Speed: 3.1ms preprocess, 815.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 755.2ms
# Speed: 5.0ms preprocess, 755.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 984.5ms
# Speed: 2.9ms preprocess, 984.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 736.6ms
# Speed: 2.0ms preprocess, 736.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 727.7ms
# Speed: 2.0ms preprocess, 727.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 754.1ms
# Speed: 3.1ms preprocess, 754.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 735.2ms
# Speed: 4.8ms preprocess, 735.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 pills, 729.0ms
# Speed: 3.5ms preprocess, 729.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 (no detections), 741.8ms
# Speed: 3.3ms preprocess, 741.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 776.7ms
# Speed: 5.5ms preprocess, 776.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 676.0ms
# Speed: 1.9ms preprocess, 676.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 708.3ms
# Speed: 11.3ms preprocess, 708.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 732.2ms
# Speed: 2.5ms preprocess, 732.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 703.1ms
# Speed: 5.8ms preprocess, 703.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 704.7ms
# Speed: 3.4ms preprocess, 704.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 730.1ms
# Speed: 4.5ms preprocess, 730.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 732.3ms
# Speed: 8.3ms preprocess, 732.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 714.9ms
# Speed: 3.5ms preprocess, 714.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 743.2ms
# Speed: 3.0ms preprocess, 743.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 728.9ms
# Speed: 2.5ms preprocess, 728.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 735.2ms
# Speed: 3.0ms preprocess, 735.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 717.8ms
# Speed: 2.9ms preprocess, 717.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 722.1ms
# Speed: 3.2ms preprocess, 722.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 714.6ms
# Speed: 3.4ms preprocess, 714.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 740.1ms
# Speed: 3.0ms preprocess, 740.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 754.2ms
# Speed: 3.0ms preprocess, 754.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 743.9ms
# Speed: 2.0ms preprocess, 743.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 730.4ms
# Speed: 3.0ms preprocess, 730.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 747.8ms
# Speed: 3.0ms preprocess, 747.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 778.4ms
# Speed: 3.5ms preprocess, 778.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 758.5ms
# Speed: 2.1ms preprocess, 758.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 758.1ms
# Speed: 4.6ms preprocess, 758.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 (no detections), 777.2ms
# Speed: 3.0ms preprocess, 777.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 790.6ms
# Speed: 7.1ms preprocess, 790.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 767.9ms
# Speed: 2.0ms preprocess, 767.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 763.1ms
# Speed: 7.2ms preprocess, 763.1ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 765.3ms
# Speed: 5.0ms preprocess, 765.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 729.9ms
# Speed: 3.5ms preprocess, 729.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 749.5ms
# Speed: 2.0ms preprocess, 749.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 744.9ms
# Speed: 2.9ms preprocess, 744.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 770.7ms
# Speed: 7.8ms preprocess, 770.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 751.5ms
# Speed: 3.1ms preprocess, 751.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 765.5ms
# Speed: 2.0ms preprocess, 765.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 745.0ms
# Speed: 0.0ms preprocess, 745.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 778.6ms
# Speed: 3.8ms preprocess, 778.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 784.6ms
# Speed: 1.8ms preprocess, 784.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 2 pills, 760.1ms
# Speed: 3.7ms preprocess, 760.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 715.1ms
# Speed: 2.7ms preprocess, 715.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 739.8ms
# Speed: 4.3ms preprocess, 739.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 704.1ms
# Speed: 2.0ms preprocess, 704.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 735.5ms
# Speed: 3.4ms preprocess, 735.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 721.2ms
# Speed: 3.5ms preprocess, 721.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 742.1ms
# Speed: 3.0ms preprocess, 742.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 746.5ms
# Speed: 3.0ms preprocess, 746.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 723.2ms
# Speed: 3.0ms preprocess, 723.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 752.5ms
# Speed: 3.0ms preprocess, 752.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 730.7ms
# Speed: 4.0ms preprocess, 730.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 737.2ms
# Speed: 2.0ms preprocess, 737.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 729.1ms
# Speed: 3.0ms preprocess, 729.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 722.6ms
# Speed: 2.0ms preprocess, 722.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 717.7ms
# Speed: 3.3ms preprocess, 717.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 710.1ms
# Speed: 3.0ms preprocess, 710.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 686.3ms
# Speed: 3.0ms preprocess, 686.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 739.8ms
# Speed: 3.4ms preprocess, 739.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 695.6ms
# Speed: 2.0ms preprocess, 695.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 800.1ms
# Speed: 0.0ms preprocess, 800.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 756.5ms
# Speed: 2.9ms preprocess, 756.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 782.9ms
# Speed: 2.0ms preprocess, 782.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 796.0ms
# Speed: 2.0ms preprocess, 796.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 794.9ms
# Speed: 3.0ms preprocess, 794.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 723.6ms
# Speed: 2.9ms preprocess, 723.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Class 'heart' already exists in data.yaml
#
# 0: 384x640 1 pill, 766.8ms
# Speed: 3.0ms preprocess, 766.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 867.1ms
# Speed: 6.2ms preprocess, 867.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 694.4ms
# Speed: 3.0ms preprocess, 694.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 907.8ms
# Speed: 2.0ms preprocess, 907.8ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 796.2ms
# Speed: 4.1ms preprocess, 796.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 825.8ms
# Speed: 3.0ms preprocess, 825.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 776.7ms
# Speed: 5.0ms preprocess, 776.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 745.9ms
# Speed: 2.0ms preprocess, 745.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 735.3ms
# Speed: 2.2ms preprocess, 735.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 754.0ms
# Speed: 3.0ms preprocess, 754.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 707.7ms
# Speed: 4.0ms preprocess, 707.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 788.8ms
# Speed: 3.0ms preprocess, 788.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 pills, 745.8ms
# Speed: 3.0ms preprocess, 745.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 745.2ms
# Speed: 3.1ms preprocess, 745.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 708.3ms
# Speed: 3.2ms preprocess, 708.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 869.1ms
# Speed: 4.0ms preprocess, 869.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 717.8ms
# Speed: 3.0ms preprocess, 717.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 705.1ms
# Speed: 3.0ms preprocess, 705.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 729.8ms
# Speed: 2.0ms preprocess, 729.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 772.5ms
# Speed: 3.0ms preprocess, 772.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 740.7ms
# Speed: 2.2ms preprocess, 740.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 650.1ms
# Speed: 3.0ms preprocess, 650.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 664.3ms
# Speed: 3.0ms preprocess, 664.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 2 pills, 714.0ms
# Speed: 7.2ms preprocess, 714.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 650.9ms
# Speed: 3.1ms preprocess, 650.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 656.6ms
# Speed: 0.0ms preprocess, 656.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 659.2ms
# Speed: 0.0ms preprocess, 659.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 698.3ms
# Speed: 2.0ms preprocess, 698.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 665.9ms
# Speed: 0.0ms preprocess, 665.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 630.8ms
# Speed: 10.4ms preprocess, 630.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 671.8ms
# Speed: 2.0ms preprocess, 671.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 618.7ms
# Speed: 2.9ms preprocess, 618.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 690.1ms
# Speed: 2.9ms preprocess, 690.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 690.1ms
# Speed: 3.0ms preprocess, 690.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 672.3ms
# Speed: 3.0ms preprocess, 672.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 718.8ms
# Speed: 6.0ms preprocess, 718.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 713.3ms
# Speed: 1.0ms preprocess, 713.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 760.2ms
# Speed: 0.0ms preprocess, 760.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 734.6ms
# Speed: 1.5ms preprocess, 734.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 716.0ms
# Speed: 3.6ms preprocess, 716.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 679.4ms
# Speed: 4.6ms preprocess, 679.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 752.5ms
# Speed: 3.0ms preprocess, 752.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 762.0ms
# Speed: 7.1ms preprocess, 762.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 682.1ms
# Speed: 4.0ms preprocess, 682.1ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 956.7ms
# Speed: 3.5ms preprocess, 956.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 834.4ms
# Speed: 0.0ms preprocess, 834.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 782.9ms
# Speed: 2.0ms preprocess, 782.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 786.9ms
# Speed: 3.0ms preprocess, 786.9ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 716.5ms
# Speed: 3.5ms preprocess, 716.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 694.6ms
# Speed: 1.7ms preprocess, 694.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 731.0ms
# Speed: 3.0ms preprocess, 731.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 759.6ms
# Speed: 3.0ms preprocess, 759.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 717.7ms
# Speed: 3.0ms preprocess, 717.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 714.3ms
# Speed: 2.0ms preprocess, 714.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 697.6ms
# Speed: 3.5ms preprocess, 697.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 845.3ms
# Speed: 0.0ms preprocess, 845.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 767.1ms
# Speed: 3.2ms preprocess, 767.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 782.4ms
# Speed: 2.6ms preprocess, 782.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 730.3ms
# Speed: 2.0ms preprocess, 730.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 725.6ms
# Speed: 3.0ms preprocess, 725.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 831.1ms
# Speed: 2.0ms preprocess, 831.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 759.3ms
# Speed: 3.0ms preprocess, 759.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 764.0ms
# Speed: 3.2ms preprocess, 764.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 781.8ms
# Speed: 3.0ms preprocess, 781.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 764.1ms
# Speed: 2.0ms preprocess, 764.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 733.1ms
# Speed: 2.4ms preprocess, 733.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 746.3ms
# Speed: 2.0ms preprocess, 746.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 735.6ms
# Speed: 3.0ms preprocess, 735.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 718.8ms
# Speed: 3.0ms preprocess, 718.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 733.1ms
# Speed: 4.6ms preprocess, 733.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 717.0ms
# Speed: 2.8ms preprocess, 717.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 708.3ms
# Speed: 0.0ms preprocess, 708.3ms inference, 15.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 790.7ms
# Speed: 2.0ms preprocess, 790.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 pills, 818.4ms
# Speed: 9.4ms preprocess, 818.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 720.0ms
# Speed: 3.0ms preprocess, 720.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 708.2ms
# Speed: 4.1ms preprocess, 708.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 765.4ms
# Speed: 2.0ms preprocess, 765.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 794.6ms
# Speed: 3.0ms preprocess, 794.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 713.2ms
# Speed: 2.0ms preprocess, 713.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 791.2ms
# Speed: 2.2ms preprocess, 791.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 730.5ms
# Speed: 3.2ms preprocess, 730.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 757.0ms
# Speed: 3.0ms preprocess, 757.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 726.5ms
# Speed: 2.0ms preprocess, 726.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 773.2ms
# Speed: 2.1ms preprocess, 773.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 841.3ms
# Speed: 2.0ms preprocess, 841.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 710.5ms
# Speed: 4.2ms preprocess, 710.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 800.6ms
# Speed: 0.0ms preprocess, 800.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 701.9ms
# Speed: 3.0ms preprocess, 701.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 pills, 771.6ms
# Speed: 0.0ms preprocess, 771.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 895.7ms
# Speed: 2.0ms preprocess, 895.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 797.0ms
# Speed: 0.0ms preprocess, 797.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 743.1ms
# Speed: 3.0ms preprocess, 743.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 899.7ms
# Speed: 0.0ms preprocess, 899.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 804.3ms
# Speed: 3.0ms preprocess, 804.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 702.4ms
# Speed: 13.4ms preprocess, 702.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 2 pills, 844.3ms
# Speed: 3.0ms preprocess, 844.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 753.1ms
# Speed: 4.0ms preprocess, 753.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 755.4ms
# Speed: 3.1ms preprocess, 755.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 750.4ms
# Speed: 3.1ms preprocess, 750.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 703.8ms
# Speed: 2.0ms preprocess, 703.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Class 'ibuprofen' already exists in data.yaml
#
# 0: 384x640 1 pill, 726.1ms
# Speed: 2.7ms preprocess, 726.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 705.9ms
# Speed: 2.9ms preprocess, 705.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 711.7ms
# Speed: 2.0ms preprocess, 711.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 750.3ms
# Speed: 2.0ms preprocess, 750.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 747.7ms
# Speed: 3.0ms preprocess, 747.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 757.9ms
# Speed: 3.0ms preprocess, 757.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 730.0ms
# Speed: 2.9ms preprocess, 730.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 807.6ms
# Speed: 3.2ms preprocess, 807.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 862.2ms
# Speed: 4.1ms preprocess, 862.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 843.3ms
# Speed: 2.1ms preprocess, 843.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 734.5ms
# Speed: 0.0ms preprocess, 734.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 697.0ms
# Speed: 2.1ms preprocess, 697.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 712.5ms
# Speed: 2.0ms preprocess, 712.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 686.2ms
# Speed: 2.0ms preprocess, 686.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 704.5ms
# Speed: 3.4ms preprocess, 704.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 716.6ms
# Speed: 2.0ms preprocess, 716.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 655.9ms
# Speed: 2.0ms preprocess, 655.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 700.6ms
# Speed: 1.4ms preprocess, 700.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 698.8ms
# Speed: 2.0ms preprocess, 698.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 653.9ms
# Speed: 3.0ms preprocess, 653.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 682.6ms
# Speed: 2.0ms preprocess, 682.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 663.0ms
# Speed: 2.0ms preprocess, 663.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 714.8ms
# Speed: 0.0ms preprocess, 714.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 668.5ms
# Speed: 3.0ms preprocess, 668.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 633.7ms
# Speed: 2.4ms preprocess, 633.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 660.4ms
# Speed: 2.4ms preprocess, 660.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 682.9ms
# Speed: 2.4ms preprocess, 682.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 662.6ms
# Speed: 3.0ms preprocess, 662.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 699.7ms
# Speed: 3.2ms preprocess, 699.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 694.1ms
# Speed: 3.0ms preprocess, 694.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 684.1ms
# Speed: 3.0ms preprocess, 684.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 779.6ms
# Speed: 2.4ms preprocess, 779.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 759.5ms
# Speed: 3.5ms preprocess, 759.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 765.2ms
# Speed: 0.0ms preprocess, 765.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 754.0ms
# Speed: 3.0ms preprocess, 754.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 686.4ms
# Speed: 2.0ms preprocess, 686.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 672.8ms
# Speed: 3.9ms preprocess, 672.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 697.2ms
# Speed: 0.0ms preprocess, 697.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 736.3ms
# Speed: 2.0ms preprocess, 736.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 712.6ms
# Speed: 3.0ms preprocess, 712.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 790.1ms
# Speed: 2.0ms preprocess, 790.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 800.2ms
# Speed: 0.0ms preprocess, 800.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 800.4ms
# Speed: 3.0ms preprocess, 800.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 876.8ms
# Speed: 2.2ms preprocess, 876.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 703.1ms
# Speed: 2.1ms preprocess, 703.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 839.2ms
# Speed: 0.0ms preprocess, 839.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 762.3ms
# Speed: 2.0ms preprocess, 762.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 719.3ms
# Speed: 2.0ms preprocess, 719.3ms inference, 13.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 771.9ms
# Speed: 2.9ms preprocess, 771.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 782.1ms
# Speed: 3.2ms preprocess, 782.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 712.9ms
# Speed: 2.0ms preprocess, 712.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 813.5ms
# Speed: 3.0ms preprocess, 813.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 732.0ms
# Speed: 3.6ms preprocess, 732.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 813.1ms
# Speed: 3.0ms preprocess, 813.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 732.5ms
# Speed: 3.0ms preprocess, 732.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 687.3ms
# Speed: 4.0ms preprocess, 687.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 770.5ms
# Speed: 3.0ms preprocess, 770.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 800.5ms
# Speed: 2.6ms preprocess, 800.5ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 723.5ms
# Speed: 13.4ms preprocess, 723.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 748.4ms
# Speed: 0.0ms preprocess, 748.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 732.3ms
# Speed: 2.0ms preprocess, 732.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 721.4ms
# Speed: 2.0ms preprocess, 721.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 749.4ms
# Speed: 4.1ms preprocess, 749.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 750.2ms
# Speed: 2.9ms preprocess, 750.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 692.6ms
# Speed: 2.4ms preprocess, 692.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 730.2ms
# Speed: 2.0ms preprocess, 730.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 810.9ms
# Speed: 2.7ms preprocess, 810.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 738.8ms
# Speed: 2.3ms preprocess, 738.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 742.1ms
# Speed: 2.1ms preprocess, 742.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 786.5ms
# Speed: 0.0ms preprocess, 786.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 811.5ms
# Speed: 2.3ms preprocess, 811.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 817.3ms
# Speed: 0.0ms preprocess, 817.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 767.9ms
# Speed: 2.0ms preprocess, 767.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 827.3ms
# Speed: 2.0ms preprocess, 827.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 784.7ms
# Speed: 3.5ms preprocess, 784.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 677.9ms
# Speed: 2.0ms preprocess, 677.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 832.5ms
# Speed: 0.0ms preprocess, 832.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 766.3ms
# Speed: 4.5ms preprocess, 766.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 748.7ms
# Speed: 3.5ms preprocess, 748.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 743.5ms
# Speed: 0.0ms preprocess, 743.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 757.6ms
# Speed: 2.0ms preprocess, 757.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 760.7ms
# Speed: 15.1ms preprocess, 760.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 743.5ms
# Speed: 2.0ms preprocess, 743.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 655.5ms
# Speed: 4.0ms preprocess, 655.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 740.1ms
# Speed: 2.0ms preprocess, 740.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 711.2ms
# Speed: 2.0ms preprocess, 711.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 685.7ms
# Speed: 3.0ms preprocess, 685.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 663.1ms
# Speed: 2.6ms preprocess, 663.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 678.9ms
# Speed: 3.0ms preprocess, 678.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 696.4ms
# Speed: 2.0ms preprocess, 696.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 685.5ms
# Speed: 2.0ms preprocess, 685.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 708.0ms
# Speed: 2.9ms preprocess, 708.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 688.3ms
# Speed: 3.0ms preprocess, 688.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 668.7ms
# Speed: 12.1ms preprocess, 668.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 665.3ms
# Speed: 2.0ms preprocess, 665.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 689.2ms
# Speed: 0.0ms preprocess, 689.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 610.4ms
# Speed: 16.2ms preprocess, 610.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 662.7ms
# Speed: 2.0ms preprocess, 662.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 685.7ms
# Speed: 2.0ms preprocess, 685.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 716.0ms
# Speed: 3.0ms preprocess, 716.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Class 'nausea' added to data.yaml
#
# 0: 384x640 1 pill, 670.8ms
# Speed: 2.5ms preprocess, 670.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 679.4ms
# Speed: 2.0ms preprocess, 679.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 657.7ms
# Speed: 2.4ms preprocess, 657.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 724.6ms
# Speed: 6.9ms preprocess, 724.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 742.4ms
# Speed: 2.0ms preprocess, 742.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 712.2ms
# Speed: 2.0ms preprocess, 712.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 698.6ms
# Speed: 3.0ms preprocess, 698.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 688.3ms
# Speed: 1.6ms preprocess, 688.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 743.5ms
# Speed: 0.0ms preprocess, 743.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 676.7ms
# Speed: 3.3ms preprocess, 676.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 799.8ms
# Speed: 2.6ms preprocess, 799.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 682.6ms
# Speed: 2.0ms preprocess, 682.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 743.2ms
# Speed: 3.0ms preprocess, 743.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 702.2ms
# Speed: 10.8ms preprocess, 702.2ms inference, 13.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 716.7ms
# Speed: 0.0ms preprocess, 716.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 716.3ms
# Speed: 2.4ms preprocess, 716.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 700.0ms
# Speed: 0.0ms preprocess, 700.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 721.8ms
# Speed: 0.0ms preprocess, 721.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 693.6ms
# Speed: 6.1ms preprocess, 693.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 697.9ms
# Speed: 6.8ms preprocess, 697.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 761.4ms
# Speed: 3.2ms preprocess, 761.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 760.7ms
# Speed: 2.0ms preprocess, 760.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 805.5ms
# Speed: 2.0ms preprocess, 805.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 775.4ms
# Speed: 3.0ms preprocess, 775.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 2 pills, 751.6ms
# Speed: 1.7ms preprocess, 751.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 700.6ms
# Speed: 1.9ms preprocess, 700.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 695.8ms
# Speed: 0.0ms preprocess, 695.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 794.3ms
# Speed: 14.5ms preprocess, 794.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 719.5ms
# Speed: 0.0ms preprocess, 719.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 698.1ms
# Speed: 0.0ms preprocess, 698.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 685.8ms
# Speed: 15.6ms preprocess, 685.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 735.3ms
# Speed: 14.0ms preprocess, 735.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 786.0ms
# Speed: 0.0ms preprocess, 786.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 699.5ms
# Speed: 0.0ms preprocess, 699.5ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 813.5ms
# Speed: 17.4ms preprocess, 813.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 800.8ms
# Speed: 6.0ms preprocess, 800.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 746.3ms
# Speed: 0.0ms preprocess, 746.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 741.4ms
# Speed: 3.0ms preprocess, 741.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 753.1ms
# Speed: 15.6ms preprocess, 753.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 775.0ms
# Speed: 0.0ms preprocess, 775.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 717.4ms
# Speed: 2.0ms preprocess, 717.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 712.5ms
# Speed: 0.0ms preprocess, 712.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 799.2ms
# Speed: 3.0ms preprocess, 799.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 730.6ms
# Speed: 0.0ms preprocess, 730.6ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 740.9ms
# Speed: 2.1ms preprocess, 740.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 723.6ms
# Speed: 2.9ms preprocess, 723.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 756.0ms
# Speed: 4.0ms preprocess, 756.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 763.3ms
# Speed: 3.1ms preprocess, 763.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 696.4ms
# Speed: 0.0ms preprocess, 696.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 941.0ms
# Speed: 11.3ms preprocess, 941.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 714.8ms
# Speed: 4.3ms preprocess, 714.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 707.7ms
# Speed: 2.4ms preprocess, 707.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 704.5ms
# Speed: 2.9ms preprocess, 704.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 728.6ms
# Speed: 0.0ms preprocess, 728.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 789.2ms
# Speed: 3.0ms preprocess, 789.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 723.4ms
# Speed: 1.0ms preprocess, 723.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 746.0ms
# Speed: 3.0ms preprocess, 746.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 711.9ms
# Speed: 2.5ms preprocess, 711.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 761.2ms
# Speed: 0.9ms preprocess, 761.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 699.6ms
# Speed: 3.0ms preprocess, 699.6ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 734.9ms
# Speed: 3.0ms preprocess, 734.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 718.2ms
# Speed: 2.0ms preprocess, 718.2ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 724.0ms
# Speed: 3.1ms preprocess, 724.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 698.3ms
# Speed: 0.0ms preprocess, 698.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 703.0ms
# Speed: 0.0ms preprocess, 703.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 790.7ms
# Speed: 2.4ms preprocess, 790.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 821.7ms
# Speed: 0.0ms preprocess, 821.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 687.5ms
# Speed: 8.6ms preprocess, 687.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 710.6ms
# Speed: 1.9ms preprocess, 710.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 688.5ms
# Speed: 2.5ms preprocess, 688.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 762.3ms
# Speed: 0.0ms preprocess, 762.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 748.1ms
# Speed: 0.0ms preprocess, 748.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 707.5ms
# Speed: 13.9ms preprocess, 707.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 828.2ms
# Speed: 1.7ms preprocess, 828.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 826.9ms
# Speed: 3.2ms preprocess, 826.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 727.5ms
# Speed: 32.4ms preprocess, 727.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 735.0ms
# Speed: 2.5ms preprocess, 735.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 805.1ms
# Speed: 4.0ms preprocess, 805.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 760.0ms
# Speed: 1.6ms preprocess, 760.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 702.8ms
# Speed: 1.4ms preprocess, 702.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 753.2ms
# Speed: 7.2ms preprocess, 753.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 757.5ms
# Speed: 2.0ms preprocess, 757.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 696.8ms
# Speed: 3.0ms preprocess, 696.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 775.8ms
# Speed: 0.0ms preprocess, 775.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 769.2ms
# Speed: 2.6ms preprocess, 769.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 775.0ms
# Speed: 3.9ms preprocess, 775.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 918.3ms
# Speed: 0.0ms preprocess, 918.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 733.3ms
# Speed: 2.4ms preprocess, 733.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 736.1ms
# Speed: 1.8ms preprocess, 736.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 722.5ms
# Speed: 1.4ms preprocess, 722.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 732.0ms
# Speed: 0.0ms preprocess, 732.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 800.4ms
# Speed: 0.0ms preprocess, 800.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 744.2ms
# Speed: 3.0ms preprocess, 744.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 730.4ms
# Speed: 3.0ms preprocess, 730.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 764.2ms
# Speed: 0.0ms preprocess, 764.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 686.0ms
# Speed: 0.0ms preprocess, 686.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 767.8ms
# Speed: 0.0ms preprocess, 767.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 762.1ms
# Speed: 13.5ms preprocess, 762.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 734.5ms
# Speed: 15.0ms preprocess, 734.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 857.5ms
# Speed: 16.7ms preprocess, 857.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Class 'panadol' added to data.yaml
#
# 0: 640x384 1 pill, 790.0ms
# Speed: 13.5ms preprocess, 790.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 1086.2ms
# Speed: 3.0ms preprocess, 1086.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 951.1ms
# Speed: 13.5ms preprocess, 951.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 794.8ms
# Speed: 2.9ms preprocess, 794.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 723.9ms
# Speed: 3.0ms preprocess, 723.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 712.0ms
# Speed: 2.0ms preprocess, 712.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 676.5ms
# Speed: 3.0ms preprocess, 676.5ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 699.2ms
# Speed: 0.0ms preprocess, 699.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 706.3ms
# Speed: 0.0ms preprocess, 706.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 684.2ms
# Speed: 16.6ms preprocess, 684.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 725.9ms
# Speed: 5.5ms preprocess, 725.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 750.1ms
# Speed: 0.0ms preprocess, 750.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 746.8ms
# Speed: 5.3ms preprocess, 746.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 683.7ms
# Speed: 16.7ms preprocess, 683.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 738.1ms
# Speed: 3.3ms preprocess, 738.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 691.8ms
# Speed: 12.7ms preprocess, 691.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 718.5ms
# Speed: 0.0ms preprocess, 718.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 718.4ms
# Speed: 2.0ms preprocess, 718.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 784.0ms
# Speed: 2.6ms preprocess, 784.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 715.8ms
# Speed: 3.3ms preprocess, 715.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 699.6ms
# Speed: 0.0ms preprocess, 699.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 693.3ms
# Speed: 13.6ms preprocess, 693.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 727.1ms
# Speed: 2.0ms preprocess, 727.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 645.9ms
# Speed: 3.3ms preprocess, 645.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 714.2ms
# Speed: 3.1ms preprocess, 714.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 766.6ms
# Speed: 3.3ms preprocess, 766.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 737.1ms
# Speed: 15.5ms preprocess, 737.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 719.1ms
# Speed: 0.0ms preprocess, 719.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 764.5ms
# Speed: 3.0ms preprocess, 764.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 700.9ms
# Speed: 3.0ms preprocess, 700.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 693.2ms
# Speed: 3.0ms preprocess, 693.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 713.7ms
# Speed: 5.7ms preprocess, 713.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 704.7ms
# Speed: 3.3ms preprocess, 704.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 720.7ms
# Speed: 0.0ms preprocess, 720.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 704.7ms
# Speed: 2.0ms preprocess, 704.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 719.8ms
# Speed: 2.4ms preprocess, 719.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 750.7ms
# Speed: 2.5ms preprocess, 750.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 791.2ms
# Speed: 0.0ms preprocess, 791.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 721.7ms
# Speed: 15.3ms preprocess, 721.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 737.3ms
# Speed: 3.0ms preprocess, 737.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 774.2ms
# Speed: 16.3ms preprocess, 774.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 764.0ms
# Speed: 2.3ms preprocess, 764.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 776.8ms
# Speed: 0.0ms preprocess, 776.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 784.5ms
# Speed: 0.0ms preprocess, 784.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 706.7ms
# Speed: 0.0ms preprocess, 706.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 841.7ms
# Speed: 2.0ms preprocess, 841.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 718.0ms
# Speed: 3.0ms preprocess, 718.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 673.5ms
# Speed: 3.0ms preprocess, 673.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 743.4ms
# Speed: 1.2ms preprocess, 743.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 700.3ms
# Speed: 3.0ms preprocess, 700.3ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 734.4ms
# Speed: 2.0ms preprocess, 734.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 714.7ms
# Speed: 3.0ms preprocess, 714.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 685.4ms
# Speed: 3.0ms preprocess, 685.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 734.3ms
# Speed: 5.2ms preprocess, 734.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 735.6ms
# Speed: 2.0ms preprocess, 735.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 735.2ms
# Speed: 6.9ms preprocess, 735.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 748.6ms
# Speed: 2.0ms preprocess, 748.6ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 732.9ms
# Speed: 2.0ms preprocess, 732.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 708.6ms
# Speed: 3.0ms preprocess, 708.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 679.8ms
# Speed: 2.0ms preprocess, 679.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 722.0ms
# Speed: 5.2ms preprocess, 722.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 701.8ms
# Speed: 20.7ms preprocess, 701.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 682.1ms
# Speed: 3.6ms preprocess, 682.1ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 776.7ms
# Speed: 14.5ms preprocess, 776.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 735.7ms
# Speed: 0.0ms preprocess, 735.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 730.8ms
# Speed: 2.7ms preprocess, 730.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 747.4ms
# Speed: 2.0ms preprocess, 747.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 739.9ms
# Speed: 2.0ms preprocess, 739.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 763.3ms
# Speed: 3.0ms preprocess, 763.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 772.2ms
# Speed: 3.7ms preprocess, 772.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 762.2ms
# Speed: 3.0ms preprocess, 762.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 744.9ms
# Speed: 3.0ms preprocess, 744.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 810.0ms
# Speed: 3.0ms preprocess, 810.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 722.4ms
# Speed: 3.0ms preprocess, 722.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 784.8ms
# Speed: 2.0ms preprocess, 784.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 799.4ms
# Speed: 4.1ms preprocess, 799.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 699.7ms
# Speed: 3.0ms preprocess, 699.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 750.4ms
# Speed: 2.7ms preprocess, 750.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 719.1ms
# Speed: 4.0ms preprocess, 719.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 730.2ms
# Speed: 0.0ms preprocess, 730.2ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 716.8ms
# Speed: 13.5ms preprocess, 716.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 701.7ms
# Speed: 2.0ms preprocess, 701.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 725.1ms
# Speed: 3.4ms preprocess, 725.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 745.0ms
# Speed: 3.2ms preprocess, 745.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 835.8ms
# Speed: 3.0ms preprocess, 835.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 749.7ms
# Speed: 3.8ms preprocess, 749.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 766.1ms
# Speed: 3.4ms preprocess, 766.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 694.9ms
# Speed: 0.0ms preprocess, 694.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 742.7ms
# Speed: 0.0ms preprocess, 742.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 710.4ms
# Speed: 3.3ms preprocess, 710.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pill, 746.0ms
# Speed: 3.0ms preprocess, 746.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 777.6ms
# Speed: 2.3ms preprocess, 777.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 687.6ms
# Speed: 7.0ms preprocess, 687.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 704.8ms
# Speed: 3.0ms preprocess, 704.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 709.3ms
# Speed: 2.0ms preprocess, 709.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 763.1ms
# Speed: 0.0ms preprocess, 763.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 1 pill, 743.6ms
# Speed: 2.0ms preprocess, 743.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 726.1ms
# Speed: 3.0ms preprocess, 726.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 pill, 698.4ms
# Speed: 29.7ms preprocess, 698.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x640 1 pill, 675.7ms
# Speed: 3.0ms preprocess, 675.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Annotation complete.

# %%
import os
import shutil
import pandas as pd

# Set the paths for the original and augmented folders
annotated_folder = "./Annotated/"
merged_folder = "./Merged_Images/"

# Create the merged folder if it doesn't exist
if not os.path.exists(merged_folder):
    os.makedirs(merged_folder)

# Function to copy images and their corresponding txt files
def copy_images_and_txt(src_folder, dest_folder):
    for class_folder in os.listdir(src_folder):
        class_path = os.path.join(src_folder, class_folder)
        if os.path.isdir(class_path):
            for root, dirs, files in os.walk(class_path):
                for filename in files:
                    # Check if the file is an image (png, jpg, jpeg, etc.)
                    if any(filename.lower().endswith(ext) for ext in ['.png', '.jpg', '.jpeg']):
                        image_path = os.path.join(root, filename)
                        txt_path = os.path.join(root, filename.rsplit(".", 1)[0] + ".txt")

                        # Copy the image to the merged folder
                        shutil.copy(image_path, dest_folder)

                        # Copy the corresponding txt file if it exists
                        if os.path.exists(txt_path):
                            shutil.copy(txt_path, dest_folder)

# Copy annotated images and txt files
copy_images_and_txt(annotated_folder, merged_folder)

# Create a Pandas DataFrame to store the data
data = []

# Iterate through the merged folder and read txt files
for root, dirs, files in os.walk(merged_folder):
    for filename in files:
        if filename.lower().endswith('.txt'):
            txt_path = os.path.join(root, filename)
            with open(txt_path, 'r') as txt_file:
                content = txt_file.read().split()
                file_name = os.path.splitext(filename)[0]
                class_label = int(content[0])  # Assuming the class is the first value in the txt file
                data.append([file_name, class_label])

# Create a DataFrame
df = pd.DataFrame(data, columns=['Original_File', 'Class'])

# %%
df
# Out:
#                                          Original_File  Class
# 0    gastric_original_gastric1.jpeg_05411852-f9eb-4...      0
# 1    gastric_original_gastric1.jpeg_0e2205b2-051d-4...      0
# 2    gastric_original_gastric1.jpeg_17ee0750-efb0-4...      0
# 3    gastric_original_gastric1.jpeg_185e3781-0cb2-4...      0
# 4    gastric_original_gastric1.jpeg_191e87ce-3ac9-4...      0
# ..                                                 ...    ...
# 478  panadol_original_panadol2.jpeg_e43e09d8-b6de-4...      4
# 479  panadol_original_panadol2.jpeg_ea9c5921-60be-4...      4
# 480  panadol_original_panadol2.jpeg_eaa06108-499c-4...      4
# 481  panadol_original_panadol2.jpeg_eb87da5d-489e-4...      4
# 482  panadol_original_panadol2.jpeg_f6de1ccb-7955-4...      4
#
# [483 rows x 2 columns]

# %%
import os
import shutil
import pandas as pd
from sklearn.model_selection import train_test_split

# Set the paths for the folders to store train, test, and val data
train_folder = "./Merged_Images/train/"
test_folder = "./Merged_Images/test/"
val_folder = "./Merged_Images/val/"

# Create train, test, and val folders if they don't exist
for folder in [train_folder, test_folder, val_folder]:
    if not os.path.exists(folder):
        os.makedirs(folder)
        os.makedirs(os.path.join(folder, "images"))
        os.makedirs(os.path.join(folder, "labels"))

# Use train_test_split with stratify to maintain class distribution
train_df, test_val_df = train_test_split(df, test_size=0.3, stratify=df['Class'], random_state=42)
test_df, val_df = train_test_split(test_val_df, test_size=0.5, stratify=test_val_df['Class'], random_state=42)

def move_files(df, destination_folder):
    for _, row in df.iterrows():
        original_file = row['Original_File']
        image_path = os.path.join(merged_folder, original_file + '.jpeg')
        txt_path = os.path.join(merged_folder, original_file + '.txt')

        # Move images to the destination folder
        shutil.move(image_path, os.path.join(destination_folder, "images"))

        # Move corresponding txt files to the destination folder
        shutil.move(txt_path, os.path.join(destination_folder, "labels"))

# Move images and labels for the train set
move_files(train_df, train_folder)

# Move images and labels for the test set
move_files(test_df, test_folder)

# Move images and labels for the validation set
move_files(val_df, val_folder)

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E6EB-988B
#
#  Directory of C:\Users\fangg\OneDrive\Documents\FYP\FSP_IVideoAnalytics\Andrew\Pill-Detection\Notebooks\FYP_yolov8
#
# 21/12/2023  02:41 pm    <DIR>          .
# 21/12/2023  11:29 am    <DIR>          ..
# 20/12/2023  08:46 am    <DIR>          .ipynb_checkpoints
# 17/12/2023  06:15 pm    <DIR>          Annotated
# 21/12/2023  02:41 pm           100,641 auto_annotation.ipynb
# 17/12/2023  06:15 pm                69 data.yaml
# 17/12/2023  12:16 am        87,647,849 detect_pills.pt
# 18/12/2023  10:56 am        80,865,154 detect_pills.zip
# 21/12/2023  02:40 pm    <DIR>          Merged_Images
# 20/12/2023  09:18 am             1,370 setup_guide.txt
# 20/12/2023  01:46 pm               306 test.py
# 18/12/2023  05:15 pm           168,489 test_pill.jpg
# 18/12/2023  05:17 pm            90,738 test_pill2.jpeg
# 17/12/2023  05:31 pm    <DIR>          Upload_Image
#                8 File(s)    168,874,616 bytes
#                6 Dir(s)  191,833,812,992 bytes free

# %%
from ultralytics import settings
print(settings)
# Out:
# {'settings_version': '0.0.4', 'datasets_dir': 'C:\\Users\\fangg\\OneDrive\\Documents\\FYP\\FSP_IVideoAnalytics\\Andrew\\Pill-Detection\\Notebooks\\yolo\\yolov5\\datasets', 'weights_dir': 'weights', 'runs_dir': 'runs', 'uuid': '8adb090acdbf98e56feb8466776c57f0ade163cc4437393577ad883621649c53', 'sync': True, 'api_key': '', 'clearml': True, 'comet': True, 'dvc': True, 'hub': True, 'mlflow': True, 'neptune': True, 'raytune': True, 'tensorboard': True, 'wandb': True}

# %%
# !pwd
# update directory to location where the yaml file is stored.
settings.update({'datasets_dir': r'C:\Users\fangg\OneDrive\Documents\FYP\FSP_IVideoAnalytics\Andrew\Pill-Detection\Notebooks\FYP_yolov8'})

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=train.yaml epochs=50 imgsz=640 batch=16
